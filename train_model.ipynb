# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# Parameters
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 20
DATASET_DIR = 'dataset'  # Make sure this is in the same folder as your notebook

# Data Augmentation + Preprocessing
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

train_generator = datagen.flow_from_directory(
    DATASET_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    DATASET_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Define Model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    MaxPooling2D(2, 2),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # 3 classes
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Checkpoint to save the best model
checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# Early stopping to prevent overfitting
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Train the model
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[checkpoint, early_stop]
)

# Plotting Accuracy and Loss
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Evaluate on validation data
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"\nValidation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")

# Load the best model later if needed
# model = load_model('best_model.h5')
# Out:
# Found 18736 images belonging to 3 classes.
# Found 4684 images belonging to 3 classes.
# C:\Users\saura\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\saura\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6422 - loss: 0.7387
# Epoch 1: val_accuracy improved from -inf to 0.74680, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1137s 2s/step - accuracy: 0.6423 - loss: 0.7384 - val_accuracy: 0.7468 - val_loss: 0.7868
# Epoch 2/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7619 - loss: 0.4788
# Epoch 2: val_accuracy improved from 0.74680 to 0.74915, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 813s 1s/step - accuracy: 0.7619 - loss: 0.4788 - val_accuracy: 0.7491 - val_loss: 1.3714
# Epoch 3/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7774 - loss: 0.4438
# Epoch 3: val_accuracy did not improve from 0.74915
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 809s 1s/step - accuracy: 0.7774 - loss: 0.4438 - val_accuracy: 0.7449 - val_loss: 0.9412
# Epoch 4/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7971 - loss: 0.4234
# Epoch 4: val_accuracy improved from 0.74915 to 0.77178, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 817s 1s/step - accuracy: 0.7971 - loss: 0.4234 - val_accuracy: 0.7718 - val_loss: 0.8353
# Epoch 5/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8060 - loss: 0.4056
# Epoch 5: val_accuracy did not improve from 0.77178
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 810s 1s/step - accuracy: 0.8060 - loss: 0.4056 - val_accuracy: 0.7669 - val_loss: 0.7055
# Epoch 6/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8136 - loss: 0.3946
# Epoch 6: val_accuracy improved from 0.77178 to 0.77968, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 813s 1s/step - accuracy: 0.8136 - loss: 0.3946 - val_accuracy: 0.7797 - val_loss: 0.8006
# Epoch 7/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8244 - loss: 0.3828
# Epoch 7: val_accuracy improved from 0.77968 to 0.79398, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1504s 3s/step - accuracy: 0.8244 - loss: 0.3828 - val_accuracy: 0.7940 - val_loss: 0.6940
# Epoch 8/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8218 - loss: 0.3772
# Epoch 8: val_accuracy did not improve from 0.79398
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1553s 3s/step - accuracy: 0.8218 - loss: 0.3771 - val_accuracy: 0.7716 - val_loss: 0.7001
# Epoch 9/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8302 - loss: 0.3603
# Epoch 9: val_accuracy improved from 0.79398 to 0.80167, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 805s 1s/step - accuracy: 0.8302 - loss: 0.3603 - val_accuracy: 0.8017 - val_loss: 0.8100
# Epoch 10/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8371 - loss: 0.3563
# Epoch 10: val_accuracy improved from 0.80167 to 0.81960, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 811s 1s/step - accuracy: 0.8371 - loss: 0.3563 - val_accuracy: 0.8196 - val_loss: 0.5737
# Epoch 11/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8354 - loss: 0.3570
# Epoch 11: val_accuracy did not improve from 0.81960
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 809s 1s/step - accuracy: 0.8354 - loss: 0.3570 - val_accuracy: 0.7643 - val_loss: 0.7887
# Epoch 12/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8386 - loss: 0.3490
# Epoch 12: val_accuracy did not improve from 0.81960
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 813s 1s/step - accuracy: 0.8387 - loss: 0.3490 - val_accuracy: 0.8061 - val_loss: 0.8127
# Epoch 13/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8442 - loss: 0.3429
# Epoch 13: val_accuracy did not improve from 0.81960
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 813s 1s/step - accuracy: 0.8442 - loss: 0.3429 - val_accuracy: 0.7916 - val_loss: 1.0950
# Epoch 14/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8455 - loss: 0.3405
# Epoch 14: val_accuracy did not improve from 0.81960
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 814s 1s/step - accuracy: 0.8455 - loss: 0.3405 - val_accuracy: 0.8164 - val_loss: 0.8771
# Epoch 15/20
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8508 - loss: 0.3266
# Epoch 15: val_accuracy improved from 0.81960 to 0.83924, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 815s 1s/step - accuracy: 0.8508 - loss: 0.3266 - val_accuracy: 0.8392 - val_loss: 0.9054
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 130s 885ms/step - accuracy: 0.8185 - loss: 0.5920
#
# Validation Loss: 0.5753
# Validation Accuracy: 0.8215
